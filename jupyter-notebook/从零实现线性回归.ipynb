# %%
import random
import torch
from d2l import torch as d2l

# %% [markdown]
# #### 构造数据集
# 根据有噪声的线性模型构造一个人造数据集。使用线性模型参数w=[2,-3.4]T、b=4.2和噪声项c生成数据集及其标签：
# y=Xw+b+c

# %%
def synthetic_data(w,b,num_examples):
    X=torch.normal(0,1,(num_examples,len(w))) # 生成均值为0，方差为1的随机数，n个样本，列数是w的长度
    y=torch.matmul(X,w)+b
    y+=torch.normal(0,0.01,y.shape)     # 加入一个随机噪音
    return X,y.reshape((-1,1))
true_w=torch.tensor([2,-3.4])
true_b=4.2
features,labels=synthetic_data(true_w,true_b,1000)

# %% [markdown]
# #### features中的每一行都包含一个二维数据样本，label每一行都含一维标签纸（一个标量）

# %%
features[0],labels[0]
# Out:
# (tensor([0.7355, 0.6886]), tensor([3.3370]))

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:,1].detach().numpy(),
                labels.detach().numpy(),1);

# %% [markdown]
# #### 定义一个data_iter函数，该函数接受批量大小、特征矩阵和标签向量作为输入，生成大小为batch_size的小批量

# %%
def data_iter(batch_size,features,labels):
    num_examples = len(features)
    # 生成每个样本的下标
    indices = list(range(num_examples))
    # 这些样本是随机抽取的，没有特定的顺序
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size): # 每次[0,num_examples],每次跳batch_size个大小
        batch_indices = torch.tensor(
            indices[i:min(i+batch_size,num_examples)])
        yield features[batch_indices],labels[batch_indices]

batch_size=10
for X,y in data_iter(batch_size,features,labels):
    print(X,'\n',y)
    break
# Out:
# tensor([[-0.8311,  0.3003],
#         [-0.0132, -0.8637],
#         [-1.9336, -0.1158],
#         [ 0.8082,  0.3916],
#         [-0.1963, -1.5764],
#         [-0.8145, -0.7917],
#         [ 0.1658, -1.3277],
#         [-1.7360, -0.5216],
#         [ 2.5427,  0.4828],
#         [ 0.2859, -2.8564]])
#  tensor([[ 1.5248],
#         [ 7.0942],
#         [ 0.7166],
#         [ 4.4898],
#         [ 9.1536],
#         [ 5.2633],
#         [ 9.0578],
#         [ 2.5025],
#         [ 7.6313],
#         [14.4775]])

# %% [markdown]
# #### 定义 初始化模型参数

# %%
w = torch.normal(0,0.01,size=(2,1),requires_grad=True)
b = torch.zeros(1,requires_grad=True)

# %% [markdown]
# #### 定义模型

# %%
def linreg(X,w,b):
    return torch.matmul(X,w)+b  # 矩阵x向量+偏差

# %% [markdown]
# #### 定义损失函数

# %%
def squared_loss(y_hat,y):
    return (y_hat - y.reshape(y_hat.shape))**2/2

# %% [markdown]
# #### 定义优化算法

# %%
def sgd(params,lr,batch_size):
    with torch.no_grad():
        for param in params:   # 更新时候，不需要加入梯度计算
            param -= lr*param.grad/batch_size
            param.grad.zero_()

# %% [markdown]
# #### 训练过程

# %%
lr = 0.03  # 学习率
num_epochs = 3 # 整个数据扫三遍
net = linreg
loss = squared_loss

for epoch in range(num_epochs):              # 每一次对数据扫一遍
    for X,y in data_iter(batch_size,features,labels):
        l = loss(net(X,w,b),y)               # X和y的小批量损失
        # 因为l形状是批量大小的向量
        # 求和之后计算梯度
        l.sum().backward()
        sgd([w,b],lr,batch_size)             # 使用参数的梯度更新参数
        with torch.no_grad():
            train_l = loss(net(features,w,b),labels)
            print(f'epoch {epoch+1},loss{float(train_l.mean()):f}')
# Out:
# epoch 1,loss13.366604
# epoch 1,loss12.707590
# epoch 1,loss11.910878
# epoch 1,loss10.672441
# epoch 1,loss9.721087
# epoch 1,loss9.112851
# epoch 1,loss8.758143
# epoch 1,loss8.320837
# epoch 1,loss7.934376
# epoch 1,loss7.592867
# epoch 1,loss6.967983
# epoch 1,loss6.656844
# epoch 1,loss6.366518
# epoch 1,loss5.851671
# epoch 1,loss5.598140
# epoch 1,loss5.303737
# epoch 1,loss5.017625
# epoch 1,loss4.853936
# epoch 1,loss4.729239
# epoch 1,loss4.577073
# epoch 1,loss4.366355
# epoch 1,loss4.164474
# epoch 1,loss3.906973
# epoch 1,loss3.790585
# epoch 1,loss3.525737
# epoch 1,loss3.247612
# epoch 1,loss3.010244
# epoch 1,loss2.796283
# epoch 1,loss2.645617
# epoch 1,loss2.470200
# epoch 1,loss2.384008
# epoch 1,loss2.290452
# epoch 1,loss2.157037
# epoch 1,loss2.064353
# epoch 1,loss1.880002
# epoch 1,loss1.798146
# epoch 1,loss1.680276
# epoch 1,loss1.608894
# epoch 1,loss1.498942
# epoch 1,loss1.381091
# epoch 1,loss1.329083
# epoch 1,loss1.297805
# epoch 1,loss1.254373
# epoch 1,loss1.196311
# epoch 1,loss1.014221
# epoch 1,loss0.990726
# epoch 1,loss0.864879
# epoch 1,loss0.780955
# epoch 1,loss0.736504
# epoch 1,loss0.693381
# epoch 1,loss0.647415
# epoch 1,loss0.623273
# epoch 1,loss0.585732
# epoch 1,loss0.547418
# epoch 1,loss0.516053
# epoch 1,loss0.505030
# epoch 1,loss0.479493
# epoch 1,loss0.437690
# epoch 1,loss0.398391
# epoch 1,loss0.381992
# epoch 1,loss0.368822
# epoch 1,loss0.336366
# epoch 1,loss0.317358
# epoch 1,loss0.296148
# epoch 1,loss0.270146
# epoch 1,loss0.266255
# epoch 1,loss0.246449
# epoch 1,loss0.232923
# epoch 1,loss0.219797
# epoch 1,loss0.209313
# epoch 1,loss0.195889
# epoch 1,loss0.182603
# epoch 1,loss0.170099
# epoch 1,loss0.166661
# epoch 1,loss0.159325
# epoch 1,loss0.148624
# epoch 1,loss0.141162
# epoch 1,loss0.134215
# epoch 1,loss0.126863
# epoch 1,loss0.119343
# epoch 1,loss0.104714
# epoch 1,loss0.099886
# epoch 1,loss0.096340
# epoch 1,loss0.090395
# epoch 1,loss0.087979
# epoch 1,loss0.083182
# epoch 1,loss0.077141
# epoch 1,loss0.074587
# epoch 1,loss0.070081
# epoch 1,loss0.066020
# epoch 1,loss0.064128
# epoch 1,loss0.060552
# epoch 1,loss0.056961
# epoch 1,loss0.055022
# epoch 1,loss0.053087
# epoch 1,loss0.048447
# epoch 1,loss0.046376
# epoch 1,loss0.044041
# epoch 1,loss0.041934
# epoch 1,loss0.039074
# epoch 2,loss0.035330
# epoch 2,loss0.034346
# epoch 2,loss0.031923
# epoch 2,loss0.029523
# epoch 2,loss0.027009
# epoch 2,loss0.026031
# epoch 2,loss0.024974
# epoch 2,loss0.023744
# epoch 2,loss0.022987
# epoch 2,loss0.020905
# epoch 2,loss0.019906
# epoch 2,loss0.018430
# epoch 2,loss0.017182
# epoch 2,loss0.016335
# epoch 2,loss0.015677
# epoch 2,loss0.014885
# epoch 2,loss0.014373
# epoch 2,loss0.013553
# epoch 2,loss0.012869
# epoch 2,loss0.011419
# epoch 2,loss0.010729
# epoch 2,loss0.010008
# epoch 2,loss0.009446
# epoch 2,loss0.009009
# epoch 2,loss0.008546
# epoch 2,loss0.008236
# epoch 2,loss0.007818
# epoch 2,loss0.007277
# epoch 2,loss0.006668
# epoch 2,loss0.006495
# epoch 2,loss0.006215
# epoch 2,loss0.005826
# epoch 2,loss0.005569
# epoch 2,loss0.005323
# epoch 2,loss0.004872
# epoch 2,loss0.004808
# epoch 2,loss0.004599
# epoch 2,loss0.004488
# epoch 2,loss0.004379
# epoch 2,loss0.004118
# epoch 2,loss0.003890
# epoch 2,loss0.003634
# epoch 2,loss0.003518
# epoch 2,loss0.003100
# epoch 2,loss0.002920
# epoch 2,loss0.002737
# epoch 2,loss0.002586
# epoch 2,loss0.002497
# epoch 2,loss0.002308
# epoch 2,loss0.002198
# epoch 2,loss0.002066
# epoch 2,loss0.001936
# epoch 2,loss0.001869
# epoch 2,loss0.001792
# epoch 2,loss0.001728
# epoch 2,loss0.001633
# epoch 2,loss0.001517
# epoch 2,loss0.001447
# epoch 2,loss0.001377
# epoch 2,loss0.001329
# epoch 2,loss0.001225
# epoch 2,loss0.001203
# epoch 2,loss0.001142
# epoch 2,loss0.001062
# epoch 2,loss0.001000
# epoch 2,loss0.000949
# epoch 2,loss0.000889
# epoch 2,loss0.000817
# epoch 2,loss0.000786
# epoch 2,loss0.000748
# epoch 2,loss0.000709
# epoch 2,loss0.000683
# epoch 2,loss0.000644
# epoch 2,loss0.000612
# epoch 2,loss0.000596
# epoch 2,loss0.000556
# epoch 2,loss0.000526
# epoch 2,loss0.000494
# epoch 2,loss0.000470
# epoch 2,loss0.000442
# epoch 2,loss0.000419
# epoch 2,loss0.000395
# epoch 2,loss0.000365
# epoch 2,loss0.000352
# epoch 2,loss0.000325
# epoch 2,loss0.000299
# epoch 2,loss0.000288
# epoch 2,loss0.000271
# epoch 2,loss0.000260
# epoch 2,loss0.000241
# epoch 2,loss0.000228
# epoch 2,loss0.000224
# epoch 2,loss0.000210
# epoch 2,loss0.000202
# epoch 2,loss0.000195
# epoch 2,loss0.000185
# epoch 2,loss0.000173
# epoch 2,loss0.000166
# epoch 2,loss0.000160
# epoch 2,loss0.000152
# epoch 3,loss0.000142
# epoch 3,loss0.000135
# epoch 3,loss0.000131
# epoch 3,loss0.000128
# epoch 3,loss0.000124
# epoch 3,loss0.000116
# epoch 3,loss0.000111
# epoch 3,loss0.000107
# epoch 3,loss0.000103
# epoch 3,loss0.000101
# epoch 3,loss0.000099
# epoch 3,loss0.000095
# epoch 3,loss0.000092
# epoch 3,loss0.000089
# epoch 3,loss0.000086
# epoch 3,loss0.000085
# epoch 3,loss0.000083
# epoch 3,loss0.000081
# epoch 3,loss0.000079
# epoch 3,loss0.000078
# epoch 3,loss0.000077
# epoch 3,loss0.000076
# epoch 3,loss0.000075
# epoch 3,loss0.000073
# epoch 3,loss0.000072
# epoch 3,loss0.000070
# epoch 3,loss0.000069
# epoch 3,loss0.000067
# epoch 3,loss0.000066
# epoch 3,loss0.000066
# epoch 3,loss0.000065
# epoch 3,loss0.000064
# epoch 3,loss0.000063
# epoch 3,loss0.000062
# epoch 3,loss0.000061
# epoch 3,loss0.000062
# epoch 3,loss0.000061
# epoch 3,loss0.000061
# epoch 3,loss0.000060
# epoch 3,loss0.000059
# epoch 3,loss0.000059
# epoch 3,loss0.000059
# epoch 3,loss0.000058
# epoch 3,loss0.000057
# epoch 3,loss0.000057
# epoch 3,loss0.000056
# epoch 3,loss0.000056
# epoch 3,loss0.000056
# epoch 3,loss0.000056
# epoch 3,loss0.000055
# epoch 3,loss0.000055
# epoch 3,loss0.000055
# epoch 3,loss0.000055
# epoch 3,loss0.000054
# epoch 3,loss0.000054
# epoch 3,loss0.000054
# epoch 3,loss0.000054
# epoch 3,loss0.000053
# epoch 3,loss0.000053
# epoch 3,loss0.000053
# epoch 3,loss0.000052
# epoch 3,loss0.000052
# epoch 3,loss0.000051
# epoch 3,loss0.000051
# epoch 3,loss0.000051
# epoch 3,loss0.000050
# epoch 3,loss0.000050
# epoch 3,loss0.000050
# epoch 3,loss0.000050
# epoch 3,loss0.000050
# epoch 3,loss0.000050
# epoch 3,loss0.000050
# epoch 3,loss0.000050
# epoch 3,loss0.000050
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049
# epoch 3,loss0.000049

# %% [markdown]
# #### 比较真实参数和通过训练学到参数来评估训练的成功程度

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([ 0.0004, -0.0010], grad_fn=<SubBackward0>)
# b的估计误差: tensor([-6.6280e-05], grad_fn=<RsubBackward1>)
